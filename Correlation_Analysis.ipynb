# %% [markdown]
# To understand how different numeric variables in your dataset relate to each other.
#
# You'll learn:
#
# What correlation is
#
# How to calculate it
#
# How to visualize it using a heatmap
#
# How to interpret what the numbers mean
#
# 🧠 What is Correlation?
#
# Correlation tells you how strongly two numeric values move together.
#
# 📈 If both go up together → Positive correlation (close to +1)
#
# 📉 If one goes up and the other goes down → Negative correlation (close to -1)
#
# ❌ No relationship → Correlation ≈ 0
#
# 🔍 Where Do We Use This in Data Science?
#
# ✅ To see if features are related
#
# ✅ To drop redundant columns
#
# ✅ To detect possible hidden patterns
#
# ✅ To help in feature selection for ML models

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Recommended Dataset: Iris Dataset
# The Iris dataset is perfect because:
#
# It contains only numeric features: sepal length, sepal width, petal length, petal width.
#
# It’s small and clean.
#
# It’s used in ML and EDA demos worldwide.
#
# Let’s load it using seaborn:

# %%
# Load Iris dataset
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Calculate the Correlation Matrix

# %%
corr_matrix = iris.corr(numeric_only = True)
corr_matrix
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
#  Visualize the Correlation Matrix with a Heatmap

# %%
plt.figure(figsize=(8,6)) ## Set figure size
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidth=0.5)

plt.title("Correlation Heatmap - Iris Dataset")
plt.show()

#plt.figure(figsize=(8, 6)) → Makes the heatmap larger and readable.
#sns.heatmap(...) → Draws the heatmap.
#annot=True → Shows the correlation numbers inside each cell.
#cmap='coolwarm' → Uses a blue-to-red color palette (blue = negative, red = positive).
#linewidths=0.5 → Adds space between boxes for clarity.
#plt.title() → Adds a title to your chart.
#plt.show() → Displays the plot.

# %% [markdown]
# ---
# **Correlation Heatmap – Iris Dataset**
#
# 🔍 What does the heatmap show?
#
# The heatmap shows how strongly each numeric feature is correlated with the others:
#
# +1 → Perfect positive correlation
#
# -1 → Perfect negative correlation
#
# 0 → No correlation
#
# Colors help us spot patterns:
#
# 🔴 Red = Strong positive correlation
#
# 🔵 Blue = Strong negative correlation
#
# ⚪ White-ish = Weak or no correlation
#
# 💡 Key Insights from Your Heatmap:
#
# Pair = Petal length & petal width
#
# Correlation = 0.96 ✅
#
# What It Means = Very strong positive correlation. When petal length increases, petal width increases too. These two features are closely related.
#
# ---
#
# pair = Sepal length & petal length
#
# correlation = 0.87 ✅
#
# What it Means = Strong positive correlation. Longer sepals often come with longer petals.
#
# ---
#
# pair = Sepal width & petal length
#
# correlation = -0.43 🔄
#
# What it Means = Moderate negative correlation. Wider sepals tend to come with shorter petals.
#
# ---
#
# pair = Sepal width & sepal length
#
# correlation = -0.12 ❌
#
# What it Means = Weak negative correlation. Almost no clear relationship.
#
# 🤔 Why does this matter?
#
# Helps avoid multicollinearity in ML models (features too similar).
#
# Helps with feature selection — we might drop one of two highly correlated columns.
#
# Helps spot interesting biological relationships (like sepal vs petal traits in flowers 🌸).
